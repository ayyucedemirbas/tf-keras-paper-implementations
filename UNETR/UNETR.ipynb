# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, d_model, num_heads, ff_dim, filters, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.multi_head_self_attention = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.ffn = self.create_ffn(ff_dim, d_model)

        self.layer_norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layer_norm2 = layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
        self.conv1x1_1 = layers.Conv3D(filters, kernel_size=1, padding='same')
        self.conv1x1_2 = layers.Conv3D(filters, kernel_size=1, padding='same')

    def create_ffn(self, ff_dim, d_model):
        return tf.keras.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(d_model)
        ])

    def call(self, inputs):
        attn_output = self.multi_head_self_attention(inputs, inputs)
        attn_output = self.dropout1(attn_output)
        attn_output = self.conv1x1_1(attn_output)
        out1 = self.layer_norm1(inputs + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        ffn_output = self.conv1x1_2(ffn_output)

        return self.layer_norm2(out1 + ffn_output)

def UNETR(input_shape, num_classes, d_model=256, num_heads=8, ff_dim=2048, num_transformer_blocks=12, filters=64):
    inputs = tf.keras.Input(input_shape)

    # Encoding Path (U-Net)
    encoder = inputs
    skips = []

    for _ in range(4):
        encoder = layers.Conv3D(filters, kernel_size=3, activation='relu', padding='same')(encoder)
        skips.append(encoder)
        encoder = layers.MaxPooling3D(pool_size=2, strides=2)(encoder)

    encoder = layers.Conv3D(filters, kernel_size=3, activation='relu', padding='same')(encoder)

    # Transform the encoder features using transformers
    for _ in range(num_transformer_blocks):
        encoder = TransformerBlock(d_model, num_heads, ff_dim, filters)(encoder)

    # Decoding Path (U-Net)
    decoder = encoder
    for skip in reversed(skips):
        decoder = layers.Conv3DTranspose(filters, kernel_size=2, strides=2)(decoder)
        decoder = layers.Concatenate()([decoder, skip])
        decoder = layers.Conv3D(filters, kernel_size=3, activation='relu', padding='same')(decoder)

    outputs = layers.Conv3D(num_classes, kernel_size=1, activation='softmax')(decoder)

    model = Model(inputs, outputs)
    return model

# Define the input shape and number of classes
input_shape = (128, 128, 128, 1)  # Adjust dimensions based on the data
num_classes = 2  # Modify according to the task

# %%
model = UNETR(input_shape, num_classes)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 1)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1792        ['input_1[0][0]']
#                                 8, 64)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d[0][0]']
#                                 64)
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64,   110656      ['max_pooling3d[0][0]']
#                                 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_1[0][0]']
#                                 64)
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32,   110656      ['max_pooling3d_1[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_2[0][0]']
#                                 64)
#
#  conv3d_3 (Conv3D)              (None, 16, 16, 16,   110656      ['max_pooling3d_2[0][0]']
#                                 64)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 64)  0          ['conv3d_3[0][0]']
#
#  conv3d_4 (Conv3D)              (None, 8, 8, 8, 64)  110656      ['max_pooling3d_3[0][0]']
#
#  transformer_block (Transformer  (None, 8, 8, 8, 64)  1209024    ['conv3d_4[0][0]']
#  Block)
#
#  transformer_block_1 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block[0][0]']
#  erBlock)
#
#  transformer_block_2 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_1[0][0]']
#  erBlock)
#
#  transformer_block_3 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_2[0][0]']
#  erBlock)
#
#  transformer_block_4 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_3[0][0]']
#  erBlock)
#
#  transformer_block_5 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_4[0][0]']
#  erBlock)
#
#  transformer_block_6 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_5[0][0]']
#  erBlock)
#
#  transformer_block_7 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_6[0][0]']
#  erBlock)
#
#  transformer_block_8 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_7[0][0]']
#  erBlock)
#
#  transformer_block_9 (Transform  (None, 8, 8, 8, 64)  1209024    ['transformer_block_8[0][0]']
#  erBlock)
#
#  transformer_block_10 (Transfor  (None, 8, 8, 8, 64)  1209024    ['transformer_block_9[0][0]']
#  merBlock)
#
#  transformer_block_11 (Transfor  (None, 8, 8, 8, 64)  1209024    ['transformer_block_10[0][0]']
#  merBlock)
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   32832      ['transformer_block_11[0][0]']
#  ose)                           64)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 128)                              'conv3d_3[0][0]']
#
#  conv3d_29 (Conv3D)             (None, 16, 16, 16,   221248      ['concatenate[0][0]']
#                                 64)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   32832      ['conv3d_29[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_2[0][0]']
#
#  conv3d_30 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   32832      ['conv3d_30[0][0]']
#  spose)                         64)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 128)                              'conv3d_1[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 64, 64, 64,   221248      ['concatenate_2[0][0]']
#                                 64)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  32832      ['conv3d_31[0][0]']
#  spose)                         8, 64)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 128)                           'conv3d[0][0]']
#
#  conv3d_32 (Conv3D)             (None, 128, 128, 12  221248      ['concatenate_3[0][0]']
#                                 8, 64)
#
#  conv3d_33 (Conv3D)             (None, 128, 128, 12  130         ['conv3d_32[0][0]']
#                                 8, 2)
#
# ==================================================================================================
# Total params: 15,969,154
# Trainable params: 15,969,154
# Non-trainable params: 0
# __________________________________________________________________________________________________
